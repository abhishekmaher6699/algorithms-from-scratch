# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
x_train = x_train.reshape(x_train.shape[0], -1).T
x_test = x_test.reshape(x_test.shape[0], -1).T

# %%
x_train.shape
# Out:
# (784, 60000)

# %%
# Initialize parameters(W, b)

# %%
def initialize_params(current_layer, previous_layer):

  W = np.random.randn(current_layer, previous_layer) * 0.01
  b = np.zeros((current_layer, 1))
  return W, b

# %%
def initialize_lparams(layers_dim):

  params = {}
  n = len(layers_dim)
  for l in range(1, n):
    W, b = initialize_params(layers_dim[l], layers_dim[l-1])
    params['W' + str(l)] = W
    params['b' + str(l)] = b

  return params

# %%
# Forward propagation

# %%
def linear_forward(W, A, b):
    Z = np.dot(W, A) + b
    cache = (W, A, b)
    return Z, cache

# %%
# Activtaion functions

def sigmoid(Z):
  A = 1/(1 + np.exp(-Z))
  cache = Z
  return A, cache

def softmax(Z):
    exp_Z = np.exp(Z - np.max(Z, axis=0, keepdims=True))
    A = exp_Z / np.sum(exp_Z, axis=0, keepdims=True)
    cache = Z
    return A, cache

def relu(Z):
  A = np.maximum(0, Z)
  cache = Z
  return A, cache

# %%
# Function combining linear and activation functions
def linear_activation(A_prev, W, b, activ_func):

  if activ_func == 'softmax':
    Z, linear_cache = linear_forward(W, A_prev, b)
    A, Z_cache = softmax(Z)

  if activ_func == 'relu':
    Z, linear_cache = linear_forward(W, A_prev, b)
    A, Z_cache = relu(Z)

  cache = (linear_cache, Z_cache) # to use later in corresponding back-prop layer
  return A, cache

# %%
# Performing forward propagation on all layers

def forward_prop(X, params, layers_dim):

  caches = {}
  n = len(layers_dim)
  A = X

  for l in range(1,n):
      A_prev = A
      A, cache = linear_activation(A_prev, params['W' + str(l)], params['b' + str(l)], 'relu')
      caches['l' + str(l)] = cache

  AL, cache = linear_activation(A_prev, params['W' + str(l)], params['b' + str(l)], 'softmax')
  caches['l' + str(n-1)] = cache

  return AL, caches

# %%
def compute_cost(AL, Y):

  cost = -np.mean(Y * np.log(AL) + (1 - Y) * np.log(1 - AL)) #cross-entropy loss function
  return cost

# %%
# Calculating gradients of W, b and A
def linear_backward(dZ, cache):

  W, A_prev, b = cache
  m = A_prev.shape[1]

  dW = (1/m) * np.dot(dZ, A_prev.T)
  db = np.mean(dZ, axis=1, keepdims=True)
  dA = np.dot(W.T, dZ)

  return dW, db, dA

# %%
# Derivtaives of activation functions

def softmax_der(dA, cache):
  exp_Z = np.exp(cache - np.max(cache, axis=0, keepdims=True))
  softmax_Z = exp_Z / np.sum(exp_Z, axis=0, keepdims=True)

  dZ = dA * (softmax_Z * (1 - softmax_Z))
  return dZ

def relu_der(dA, cache):
  dZ = dA * (cache > 0)
  return dZ

# %%
#Combining above fuunctions to calculate dW, db, dA using previous dA
def linear_activation_backward(dA, cache, activation):

    linear_cache, activation_cache = cache

    if activation == 'softmax':
      dZ = softmax_der(dA, activation_cache)
      dW, db, dA = linear_backward(dZ, linear_cache)

    if activation == 'relu':
      dZ = relu_der(dA, activation_cache)
      dW, db, dA = linear_backward(dZ, linear_cache)

    return dW, db, dA

# %%
#Backward-propagation

def back_prop(AL, Y, caches):

  grads = {}# Stores all gradients for updating later

  dAL = - (np.divide(Y, AL) - np.divide(1 - Y, 1 - AL))# derivative of loss function wrt AL
  l = len(caches)
  current_cache = caches['l'+str(l)]
  dW, db, dA_prev = linear_activation_backward(dAL, current_cache, 'softmax')
  grads['dW' + str(l)] = dW
  grads['db' + str(l)] = db
  grads['dA' + str(l-1)] = dA_prev


  for i in reversed(range(1, l)):

    current_cache = caches['l'+str(i)]
    dW, db, dA_prev = linear_activation_backward(dA_prev, current_cache, 'relu')
    grads['dW' + str(i)] = dW
    grads['db' + str(i)] = db
    grads['dA' + str(i-1)] = dA_prev

  return grads

# %%
# Updating the parameters
def update_params(params, grads, learning_rate):
  n = len(params)//2
  for i in range(1, n+1):

    params['W'+str(i)] = params['W'+str(i)] -  learning_rate*grads['dW'+str(i)]
    params['b'+str(i)] = params['b'+str(i)] -  learning_rate*grads['db'+str(i)]

  return params

# %%
def nn_model(X, Y, layers_dim,n_iters, learning_rate):

  params = initialize_lparams(layers_dim) #parameters initialization

  for i in range(0, n_iters):

    AL, caches= forward_prop(X, params, layers_dim) # forward prop
    cost = compute_cost(AL, Y) # cost calc

    if i%10 == 0:
        print(f"Cost after {i} iterations: {cost}")
        print(f"Accuraxy after {i} iterations: {get_accuracy(np.argmax(AL,0), np.argmax(Y, axis=0))}")

    grads = back_prop(AL, Y, caches) #back-prop
    params = update_params(params, grads, learning_rate)# update parameters

  preds, _ = forward_prop(X, params, layers_dim)
  return preds, params

# %%
# transforming (1,m) shaped y array to (10, m) shaped matrix with each columns having a values that corresponds to the probability to belonging to that class
def one_hot_encode(labels):
    y = np.zeros((labels.size, labels.max()+1))
    y[np.arange(y_train.size), labels] = 1
    return y.T

Y =one_hot_encode(y_train)

# %%
def get_accuracy(pred, real):
    return np.sum(pred == real)/real.size

# %%
np.random.seed(41)
layer_dims = [784, 16, 12, 10]
preds, params = nn_model(x_train, Y, layer_dims, 3000, 0.01)
# Out:
# Cost after 0 iterations: 0.32503830379045345
# Accuraxy after 0 iterations: 0.11501666666666667
# Cost after 10 iterations: 0.32413039120462717
# Accuraxy after 10 iterations: 0.18613333333333335
# Cost after 20 iterations: 0.3202616047435505
# Accuraxy after 20 iterations: 0.22216666666666668
# Cost after 30 iterations: 0.2937691901148102
# Accuraxy after 30 iterations: 0.2549166666666667
# Cost after 40 iterations: 0.25692872666539635
# Accuraxy after 40 iterations: 0.3385666666666667
# Cost after 50 iterations: 0.23083328622063637
# Accuraxy after 50 iterations: 0.52855
# Cost after 60 iterations: 0.31384003025346685
# Accuraxy after 60 iterations: 0.1952
# Cost after 70 iterations: 0.1601195599765336
# Accuraxy after 70 iterations: 0.6992166666666667
# Cost after 80 iterations: 0.21988727838814745
# Accuraxy after 80 iterations: 0.55025
# Cost after 90 iterations: 0.1749342094020252
# Accuraxy after 90 iterations: 0.6173333333333333
# Cost after 100 iterations: 0.12809192420395352
# Accuraxy after 100 iterations: 0.7481833333333333
# Cost after 110 iterations: 0.3108863057503702
# Accuraxy after 110 iterations: 0.2629166666666667
# Cost after 120 iterations: 0.10680452287334033
# Accuraxy after 120 iterations: 0.8156166666666667
# Cost after 130 iterations: 0.08722314299726637
# Accuraxy after 130 iterations: 0.8448666666666667
# Cost after 140 iterations: 0.10760324552984711
# Accuraxy after 140 iterations: 0.78745
# Cost after 150 iterations: 0.07598824529599325
# Accuraxy after 150 iterations: 0.8675166666666667
# Cost after 160 iterations: 0.08092656978501865
# Accuraxy after 160 iterations: 0.8523333333333334
# Cost after 170 iterations: 0.0687792971088377
# Accuraxy after 170 iterations: 0.8815166666666666
# Cost after 180 iterations: 0.06408450372501627
# Accuraxy after 180 iterations: 0.8894666666666666
# Cost after 190 iterations: 0.06128629417234114
# Accuraxy after 190 iterations: 0.89415
# Cost after 200 iterations: 0.058994439868415974
# Accuraxy after 200 iterations: 0.89795
# Cost after 210 iterations: 0.05782903005965822
# Accuraxy after 210 iterations: 0.89935
# Cost after 220 iterations: 0.06249804030470067
# Accuraxy after 220 iterations: 0.886
# Cost after 230 iterations: 0.05443306151375474
# Accuraxy after 230 iterations: 0.9057333333333333
# Cost after 240 iterations: 0.0519595355575278
# Accuraxy after 240 iterations: 0.9105833333333333
# Cost after 250 iterations: 0.05053069608332965
# Accuraxy after 250 iterations: 0.913
# Cost after 260 iterations: 0.04935860227145168
# Accuraxy after 260 iterations: 0.9150833333333334
# Cost after 270 iterations: 0.049328564780916795
# Accuraxy after 270 iterations: 0.9147833333333333
# Cost after 280 iterations: 0.05775242368564547
# Accuraxy after 280 iterations: 0.89745
# Cost after 290 iterations: 0.04662397081254253
# Accuraxy after 290 iterations: 0.9198333333333333
# Cost after 300 iterations: 0.04526598324040161
# Accuraxy after 300 iterations: 0.9220833333333334
# Cost after 310 iterations: 0.0443473126784889
# Accuraxy after 310 iterations: 0.92355
# Cost after 320 iterations: 0.043552139971419795
# Accuraxy after 320 iterations: 0.9249666666666667
# Cost after 330 iterations: 0.04381110546616848
# Accuraxy after 330 iterations: 0.92415
# Cost after 340 iterations: 0.15493154903147374
# Accuraxy after 340 iterations: 0.7162333333333334
# Cost after 350 iterations: 0.043604112384334155
# Accuraxy after 350 iterations: 0.92605
# Cost after 360 iterations: 0.04183865004605005
# Accuraxy after 360 iterations: 0.9282833333333333
# Cost after 370 iterations: 0.040923306572926685
# Accuraxy after 370 iterations: 0.9296166666666666
# Cost after 380 iterations: 0.04021392754999656
# Accuraxy after 380 iterations: 0.9311166666666667
# Cost after 390 iterations: 0.03959104804638469
# Accuraxy after 390 iterations: 0.9322
# Cost after 400 iterations: 0.03901779872206489
# Accuraxy after 400 iterations: 0.93315
# Cost after 410 iterations: 0.03849190568042331
# Accuraxy after 410 iterations: 0.9338666666666666
# Cost after 420 iterations: 0.03800287178929477
# Accuraxy after 420 iterations: 0.9350166666666667
# Cost after 430 iterations: 0.03763851838935783
# Accuraxy after 430 iterations: 0.9356166666666667
# Cost after 440 iterations: 0.05082294171069473
# Accuraxy after 440 iterations: 0.9104
# Cost after 450 iterations: 0.04765228399778169
# Accuraxy after 450 iterations: 0.9230166666666667
# Cost after 460 iterations: 0.03986739291056064
# Accuraxy after 460 iterations: 0.9324
# Cost after 470 iterations: 0.03820477019903677
# Accuraxy after 470 iterations: 0.9350666666666667
# Cost after 480 iterations: 0.03729675026071359
# Accuraxy after 480 iterations: 0.9363666666666667
# Cost after 490 iterations: 0.036623341879673386
# Accuraxy after 490 iterations: 0.9375333333333333
# Cost after 500 iterations: 0.03607513464583911
# Accuraxy after 500 iterations: 0.93845
# Cost after 510 iterations: 0.035609070007629307
# Accuraxy after 510 iterations: 0.9395666666666667
# Cost after 520 iterations: 0.035192940126888575
# Accuraxy after 520 iterations: 0.9403
# Cost after 530 iterations: 0.03480873869719301
# Accuraxy after 530 iterations: 0.9413666666666667
# Cost after 540 iterations: 0.034456098587340486
# Accuraxy after 540 iterations: 0.9421
# Cost after 550 iterations: 0.03412338819087973
# Accuraxy after 550 iterations: 0.9427166666666666
# Cost after 560 iterations: 0.03380556982443554
# Accuraxy after 560 iterations: 0.94305
# Cost after 570 iterations: 0.03352473718901977
# Accuraxy after 570 iterations: 0.9435166666666667
# Cost after 580 iterations: 0.03382699412605006
# Accuraxy after 580 iterations: 0.9426333333333333
# Cost after 590 iterations: 0.11289891381514082
# Accuraxy after 590 iterations: 0.7891333333333334
# Cost after 600 iterations: 0.036532058169804274
# Accuraxy after 600 iterations: 0.9386833333333333
# Cost after 610 iterations: 0.03442962914187006
# Accuraxy after 610 iterations: 0.9416
# Cost after 620 iterations: 0.033568852243686366
# Accuraxy after 620 iterations: 0.9431333333333334
# Cost after 630 iterations: 0.03300038511439768
# Accuraxy after 630 iterations: 0.944
# Cost after 640 iterations: 0.03256010325242587
# Accuraxy after 640 iterations: 0.9449666666666666
# Cost after 650 iterations: 0.03219555949610152
# Accuraxy after 650 iterations: 0.9457333333333333
# Cost after 660 iterations: 0.03188213192855021
# Accuraxy after 660 iterations: 0.9465333333333333
# Cost after 670 iterations: 0.03160042969767952
# Accuraxy after 670 iterations: 0.94695
# Cost after 680 iterations: 0.03133977807942606
# Accuraxy after 680 iterations: 0.94725
# Cost after 690 iterations: 0.03109149667398867
# Accuraxy after 690 iterations: 0.9477166666666667
# Cost after 700 iterations: 0.030855434742130667
# Accuraxy after 700 iterations: 0.9479166666666666
# Cost after 710 iterations: 0.030631905845167604
# Accuraxy after 710 iterations: 0.9479666666666666
# Cost after 720 iterations: 0.030424935319070708
# Accuraxy after 720 iterations: 0.9484333333333334
# Cost after 730 iterations: 0.030311621522553837
# Accuraxy after 730 iterations: 0.9485166666666667
# Cost after 740 iterations: 0.03159860138354316
# Accuraxy after 740 iterations: 0.9455
# Cost after 750 iterations: 0.27497901329620245
# Accuraxy after 750 iterations: 0.6077
# Cost after 760 iterations: 0.040955801827628854
# Accuraxy after 760 iterations: 0.9298333333333333
# Cost after 770 iterations: 0.03625453465697643
# Accuraxy after 770 iterations: 0.9375333333333333
# Cost after 780 iterations: 0.034486527172317566
# Accuraxy after 780 iterations: 0.9404166666666667
# Cost after 790 iterations: 0.033456561280948136
# Accuraxy after 790 iterations: 0.9420833333333334
# Cost after 800 iterations: 0.03275981798164181
# Accuraxy after 800 iterations: 0.9434
# Cost after 810 iterations: 0.032234889990176235
# Accuraxy after 810 iterations: 0.9444833333333333
# Cost after 820 iterations: 0.03180989259444908
# Accuraxy after 820 iterations: 0.9453166666666667
# Cost after 830 iterations: 0.0314519994138022
# Accuraxy after 830 iterations: 0.94585
# Cost after 840 iterations: 0.03113932917865715
# Accuraxy after 840 iterations: 0.9466166666666667
# Cost after 850 iterations: 0.03089227999425098
# Accuraxy after 850 iterations: 0.9471833333333334
# Cost after 860 iterations: 0.031569902879271146
# Accuraxy after 860 iterations: 0.9466833333333333
# Cost after 870 iterations: 0.20560791775243853
# Accuraxy after 870 iterations: 0.5776333333333333
# Cost after 880 iterations: 0.0752176170292349
# Accuraxy after 880 iterations: 0.8537
# Cost after 890 iterations: 0.04874108910745526
# Accuraxy after 890 iterations: 0.9143833333333333
# Cost after 900 iterations: 0.042811015427342405
# Accuraxy after 900 iterations: 0.9252333333333334
# Cost after 910 iterations: 0.03998268851777195
# Accuraxy after 910 iterations: 0.9308666666666666
# Cost after 920 iterations: 0.03818763237737143
# Accuraxy after 920 iterations: 0.9338333333333333
# Cost after 930 iterations: 0.03694835645109844
# Accuraxy after 930 iterations: 0.9361166666666667
# Cost after 940 iterations: 0.036043603241370945
# Accuraxy after 940 iterations: 0.9375333333333333
# Cost after 950 iterations: 0.03533393922631723
# Accuraxy after 950 iterations: 0.9393
# Cost after 960 iterations: 0.03474840477382556
# Accuraxy after 960 iterations: 0.9401666666666667
# Cost after 970 iterations: 0.034245161817371944
# Accuraxy after 970 iterations: 0.9411833333333334
# Cost after 980 iterations: 0.0337988184824607
# Accuraxy after 980 iterations: 0.9419666666666666
# Cost after 990 iterations: 0.03339036466939539
# Accuraxy after 990 iterations: 0.9430166666666666
# Cost after 1000 iterations: 0.03301417118479376
# Accuraxy after 1000 iterations: 0.9435833333333333
# Cost after 1010 iterations: 0.03265838018170555
# Accuraxy after 1010 iterations: 0.9442166666666667
# Cost after 1020 iterations: 0.03232042545874255
# Accuraxy after 1020 iterations: 0.9447666666666666
# Cost after 1030 iterations: 0.03199786233185244
# Accuraxy after 1030 iterations: 0.9453166666666667
# Cost after 1040 iterations: 0.03169613438781232
# Accuraxy after 1040 iterations: 0.9459666666666666
# Cost after 1050 iterations: 0.031421703628140736
# Accuraxy after 1050 iterations: 0.9464833333333333
# Cost after 1060 iterations: 0.03117804688227085
# Accuraxy after 1060 iterations: 0.94695
# Cost after 1070 iterations: 0.030998855327339595
# Accuraxy after 1070 iterations: 0.9472666666666667
# Cost after 1080 iterations: 0.031059559379528687
# Accuraxy after 1080 iterations: 0.9473666666666667
# Cost after 1090 iterations: 0.032194725060479636
# Accuraxy after 1090 iterations: 0.9447
# Cost after 1100 iterations: 0.04742498896719968
# Accuraxy after 1100 iterations: 0.9142833333333333
# Cost after 1110 iterations: 0.0329987218150336
# Accuraxy after 1110 iterations: 0.9441833333333334
# Cost after 1120 iterations: 0.03119614222918993
# Accuraxy after 1120 iterations: 0.9469
# Cost after 1130 iterations: 0.030569171672779224
# Accuraxy after 1130 iterations: 0.94775
# Cost after 1140 iterations: 0.030188122038300243
# Accuraxy after 1140 iterations: 0.9486666666666667
# Cost after 1150 iterations: 0.02990809888627012
# Accuraxy after 1150 iterations: 0.9493666666666667
# Cost after 1160 iterations: 0.02967813049768435
# Accuraxy after 1160 iterations: 0.9499333333333333
# Cost after 1170 iterations: 0.029482065928162448
# Accuraxy after 1170 iterations: 0.95045
# Cost after 1180 iterations: 0.02930545074857162
# Accuraxy after 1180 iterations: 0.9508666666666666
# Cost after 1190 iterations: 0.02914282982163554
# Accuraxy after 1190 iterations: 0.9511666666666667
# Cost after 1200 iterations: 0.02899043524471259
# Accuraxy after 1200 iterations: 0.9515166666666667
# Cost after 1210 iterations: 0.028848593744803416
# Accuraxy after 1210 iterations: 0.95185
# Cost after 1220 iterations: 0.0287141056668985
# Accuraxy after 1220 iterations: 0.9520666666666666
# Cost after 1230 iterations: 0.028587151490710408
# Accuraxy after 1230 iterations: 0.9523833333333334
# Cost after 1240 iterations: 0.028468675215748213
# Accuraxy after 1240 iterations: 0.95255
# Cost after 1250 iterations: 0.028365634045188017
# Accuraxy after 1250 iterations: 0.9526666666666667
# Cost after 1260 iterations: 0.028306725484900392
# Accuraxy after 1260 iterations: 0.9527833333333333
# Cost after 1270 iterations: 0.028412647584244926
# Accuraxy after 1270 iterations: 0.9524166666666667
# Cost after 1280 iterations: 0.028933118609439663
# Accuraxy after 1280 iterations: 0.9515
# Cost after 1290 iterations: 0.03013966215980788
# Accuraxy after 1290 iterations: 0.9487
# Cost after 1300 iterations: 0.030077079210304235
# Accuraxy after 1300 iterations: 0.9488833333333333
# Cost after 1310 iterations: 0.02815307319113348
# Accuraxy after 1310 iterations: 0.9526833333333333
# Cost after 1320 iterations: 0.027735623733059517
# Accuraxy after 1320 iterations: 0.9536166666666667
# Cost after 1330 iterations: 0.02758835510228601
# Accuraxy after 1330 iterations: 0.9540833333333333
# Cost after 1340 iterations: 0.027492478231205895
# Accuraxy after 1340 iterations: 0.9542333333333334
# Cost after 1350 iterations: 0.027436543514349754
# Accuraxy after 1350 iterations: 0.9543333333333334
# Cost after 1360 iterations: 0.02746195088387283
# Accuraxy after 1360 iterations: 0.9540666666666666
# Cost after 1370 iterations: 0.027785644661348714
# Accuraxy after 1370 iterations: 0.9534666666666667
# Cost after 1380 iterations: 0.028898932309104692
# Accuraxy after 1380 iterations: 0.9514
# Cost after 1390 iterations: 0.030146673830963047
# Accuraxy after 1390 iterations: 0.9492166666666667
# Cost after 1400 iterations: 0.02770710592481478
# Accuraxy after 1400 iterations: 0.9535666666666667
# Cost after 1410 iterations: 0.026964821949481008
# Accuraxy after 1410 iterations: 0.9548833333333333
# Cost after 1420 iterations: 0.026828235023902337
# Accuraxy after 1420 iterations: 0.9551166666666666
# Cost after 1430 iterations: 0.02682945941925061
# Accuraxy after 1430 iterations: 0.9550333333333333
# Cost after 1440 iterations: 0.027246734265474935
# Accuraxy after 1440 iterations: 0.9540666666666666
# Cost after 1450 iterations: 0.03351957749482872
# Accuraxy after 1450 iterations: 0.9425666666666667
# Cost after 1460 iterations: 0.07721142742492612
# Accuraxy after 1460 iterations: 0.8390833333333333
# Cost after 1470 iterations: 0.047236293771817255
# Accuraxy after 1470 iterations: 0.92055
# Cost after 1480 iterations: 0.035812616373748225
# Accuraxy after 1480 iterations: 0.9384333333333333
# Cost after 1490 iterations: 0.033376115284459856
# Accuraxy after 1490 iterations: 0.9430333333333333
# Cost after 1500 iterations: 0.032067644610796676
# Accuraxy after 1500 iterations: 0.9454666666666667
# Cost after 1510 iterations: 0.031170845405185478
# Accuraxy after 1510 iterations: 0.9472666666666667
# Cost after 1520 iterations: 0.030495320817779364
# Accuraxy after 1520 iterations: 0.9486166666666667
# Cost after 1530 iterations: 0.029926964306179634
# Accuraxy after 1530 iterations: 0.9495166666666667
# Cost after 1540 iterations: 0.02941013634210198
# Accuraxy after 1540 iterations: 0.9503666666666667
# Cost after 1550 iterations: 0.028949646769105105
# Accuraxy after 1550 iterations: 0.9512333333333334
# Cost after 1560 iterations: 0.02850079538512904
# Accuraxy after 1560 iterations: 0.9519
# Cost after 1570 iterations: 0.028106205793069675
# Accuraxy after 1570 iterations: 0.9522833333333334
# Cost after 1580 iterations: 0.027772049434976142
# Accuraxy after 1580 iterations: 0.95295
# Cost after 1590 iterations: 0.027484169705795813
# Accuraxy after 1590 iterations: 0.95345
# Cost after 1600 iterations: 0.027226874665054683
# Accuraxy after 1600 iterations: 0.9540666666666666
# Cost after 1610 iterations: 0.026992014007334395
# Accuraxy after 1610 iterations: 0.9544166666666667
# Cost after 1620 iterations: 0.026784858338016866
# Accuraxy after 1620 iterations: 0.9549666666666666
# Cost after 1630 iterations: 0.026593527093512506
# Accuraxy after 1630 iterations: 0.9553333333333334
# Cost after 1640 iterations: 0.026423632789991432
# Accuraxy after 1640 iterations: 0.9557166666666667
# Cost after 1650 iterations: 0.026273283954858177
# Accuraxy after 1650 iterations: 0.9559666666666666
# Cost after 1660 iterations: 0.02613334581650547
# Accuraxy after 1660 iterations: 0.9560833333333333
# Cost after 1670 iterations: 0.02600546297556819
# Accuraxy after 1670 iterations: 0.9564
# Cost after 1680 iterations: 0.025892005922584144
# Accuraxy after 1680 iterations: 0.9565333333333333
# Cost after 1690 iterations: 0.02580694213470772
# Accuraxy after 1690 iterations: 0.9566833333333333
# Cost after 1700 iterations: 0.025806019579617003
# Accuraxy after 1700 iterations: 0.95685
# Cost after 1710 iterations: 0.02597044796508634
# Accuraxy after 1710 iterations: 0.95635
# Cost after 1720 iterations: 0.026570636627258552
# Accuraxy after 1720 iterations: 0.9551
# Cost after 1730 iterations: 0.028480592518846007
# Accuraxy after 1730 iterations: 0.95145
# Cost after 1740 iterations: 0.028973442992641
# Accuraxy after 1740 iterations: 0.9506166666666667
# Cost after 1750 iterations: 0.02537594284193064
# Accuraxy after 1750 iterations: 0.9578
# Cost after 1760 iterations: 0.025196675518710517
# Accuraxy after 1760 iterations: 0.9581
# Cost after 1770 iterations: 0.025101311092892268
# Accuraxy after 1770 iterations: 0.95825
# Cost after 1780 iterations: 0.0250175499001002
# Accuraxy after 1780 iterations: 0.9583
# Cost after 1790 iterations: 0.024941093712577404
# Accuraxy after 1790 iterations: 0.9583333333333334
# Cost after 1800 iterations: 0.024871555219238107
# Accuraxy after 1800 iterations: 0.9585166666666667
# Cost after 1810 iterations: 0.02481640112533676
# Accuraxy after 1810 iterations: 0.9586833333333333
# Cost after 1820 iterations: 0.024818453727784146
# Accuraxy after 1820 iterations: 0.9586333333333333
# Cost after 1830 iterations: 0.0249590096930759
# Accuraxy after 1830 iterations: 0.9584833333333334
# Cost after 1840 iterations: 0.02539718222712658
# Accuraxy after 1840 iterations: 0.9573
# Cost after 1850 iterations: 0.026406718665434082
# Accuraxy after 1850 iterations: 0.9554
# Cost after 1860 iterations: 0.027376156030962568
# Accuraxy after 1860 iterations: 0.95375
# Cost after 1870 iterations: 0.025000487941492056
# Accuraxy after 1870 iterations: 0.9581166666666666
# Cost after 1880 iterations: 0.024437465203508597
# Accuraxy after 1880 iterations: 0.9591666666666666
# Cost after 1890 iterations: 0.024322721993861
# Accuraxy after 1890 iterations: 0.9595666666666667
# Cost after 1900 iterations: 0.024254862923744697
# Accuraxy after 1900 iterations: 0.9598
# Cost after 1910 iterations: 0.024208203197945238
# Accuraxy after 1910 iterations: 0.9598666666666666
# Cost after 1920 iterations: 0.0241893155917613
# Accuraxy after 1920 iterations: 0.9598166666666667
# Cost after 1930 iterations: 0.024243778762097844
# Accuraxy after 1930 iterations: 0.9595833333333333
# Cost after 1940 iterations: 0.02453613056988254
# Accuraxy after 1940 iterations: 0.9593666666666667
# Cost after 1950 iterations: 0.025440743120691202
# Accuraxy after 1950 iterations: 0.9573833333333334
# Cost after 1960 iterations: 0.027573366679415158
# Accuraxy after 1960 iterations: 0.9534
# Cost after 1970 iterations: 0.02743515195534758
# Accuraxy after 1970 iterations: 0.9532666666666667
# Cost after 1980 iterations: 0.02392795981923096
# Accuraxy after 1980 iterations: 0.9599333333333333
# Cost after 1990 iterations: 0.023790936302306973
# Accuraxy after 1990 iterations: 0.9605333333333334
# Cost after 2000 iterations: 0.02372030046976719
# Accuraxy after 2000 iterations: 0.9606166666666667
# Cost after 2010 iterations: 0.0236656082681434
# Accuraxy after 2010 iterations: 0.9606666666666667
# Cost after 2020 iterations: 0.02362478434845461
# Accuraxy after 2020 iterations: 0.9607
# Cost after 2030 iterations: 0.023616239060508734
# Accuraxy after 2030 iterations: 0.96085
# Cost after 2040 iterations: 0.023751491423257724
# Accuraxy after 2040 iterations: 0.9607
# Cost after 2050 iterations: 0.024586733202395003
# Accuraxy after 2050 iterations: 0.95905
# Cost after 2060 iterations: 0.03101421752061621
# Accuraxy after 2060 iterations: 0.9474333333333333
# Cost after 2070 iterations: 0.11056866213139101
# Accuraxy after 2070 iterations: 0.74965
# Cost after 2080 iterations: 0.044189102380394724
# Accuraxy after 2080 iterations: 0.9234666666666667
# Cost after 2090 iterations: 0.033576525145698075
# Accuraxy after 2090 iterations: 0.94095
# Cost after 2100 iterations: 0.03068529119741747
# Accuraxy after 2100 iterations: 0.9464833333333333
# Cost after 2110 iterations: 0.028985745837113053
# Accuraxy after 2110 iterations: 0.9497166666666667
# Cost after 2120 iterations: 0.02768684138217714
# Accuraxy after 2120 iterations: 0.9522833333333334
# Cost after 2130 iterations: 0.026673908205827282
# Accuraxy after 2130 iterations: 0.9545166666666667
# Cost after 2140 iterations: 0.02596612243544254
# Accuraxy after 2140 iterations: 0.9561333333333333
# Cost after 2150 iterations: 0.025420860417725157
# Accuraxy after 2150 iterations: 0.9574333333333334
# Cost after 2160 iterations: 0.024989347186850648
# Accuraxy after 2160 iterations: 0.9580166666666666
# Cost after 2170 iterations: 0.02466436912111096
# Accuraxy after 2170 iterations: 0.95865
# Cost after 2180 iterations: 0.024412027477777622
# Accuraxy after 2180 iterations: 0.9589666666666666
# Cost after 2190 iterations: 0.024211529889408417
# Accuraxy after 2190 iterations: 0.9593666666666667
# Cost after 2200 iterations: 0.024044518704103974
# Accuraxy after 2200 iterations: 0.95965
# Cost after 2210 iterations: 0.023903416120416517
# Accuraxy after 2210 iterations: 0.9599166666666666
# Cost after 2220 iterations: 0.02378124139305356
# Accuraxy after 2220 iterations: 0.9601333333333333
# Cost after 2230 iterations: 0.02367276166833453
# Accuraxy after 2230 iterations: 0.96025
# Cost after 2240 iterations: 0.02357085725655068
# Accuraxy after 2240 iterations: 0.9603166666666667
# Cost after 2250 iterations: 0.02347668624269582
# Accuraxy after 2250 iterations: 0.9606166666666667
# Cost after 2260 iterations: 0.02338840331537243
# Accuraxy after 2260 iterations: 0.9609166666666666
# Cost after 2270 iterations: 0.02330576152068901
# Accuraxy after 2270 iterations: 0.9611333333333333
# Cost after 2280 iterations: 0.023229487404966272
# Accuraxy after 2280 iterations: 0.9611833333333333
# Cost after 2290 iterations: 0.023159508692970707
# Accuraxy after 2290 iterations: 0.9613833333333334
# Cost after 2300 iterations: 0.023095455600839185
# Accuraxy after 2300 iterations: 0.96145
# Cost after 2310 iterations: 0.023041820395828336
# Accuraxy after 2310 iterations: 0.9616
# Cost after 2320 iterations: 0.02300483131533781
# Accuraxy after 2320 iterations: 0.9618333333333333
# Cost after 2330 iterations: 0.023003120341610887
# Accuraxy after 2330 iterations: 0.9619
# Cost after 2340 iterations: 0.023045206143259375
# Accuraxy after 2340 iterations: 0.9616333333333333
# Cost after 2350 iterations: 0.023151806867713814
# Accuraxy after 2350 iterations: 0.9615
# Cost after 2360 iterations: 0.023282941437112764
# Accuraxy after 2360 iterations: 0.9613
# Cost after 2370 iterations: 0.02333460592970648
# Accuraxy after 2370 iterations: 0.9613666666666667
# Cost after 2380 iterations: 0.023188869040853977
# Accuraxy after 2380 iterations: 0.96145
# Cost after 2390 iterations: 0.02293486586677218
# Accuraxy after 2390 iterations: 0.9619833333333333
# Cost after 2400 iterations: 0.022714502408670047
# Accuraxy after 2400 iterations: 0.9624333333333334
# Cost after 2410 iterations: 0.022585226163969362
# Accuraxy after 2410 iterations: 0.9624666666666667
# Cost after 2420 iterations: 0.02249814620518784
# Accuraxy after 2420 iterations: 0.9625
# Cost after 2430 iterations: 0.022436787638525926
# Accuraxy after 2430 iterations: 0.9626666666666667
# Cost after 2440 iterations: 0.022385027608457553
# Accuraxy after 2440 iterations: 0.9627
# Cost after 2450 iterations: 0.022354348340574114
# Accuraxy after 2450 iterations: 0.9628666666666666
# Cost after 2460 iterations: 0.02236532778200488
# Accuraxy after 2460 iterations: 0.9629333333333333
# Cost after 2470 iterations: 0.02247624315003963
# Accuraxy after 2470 iterations: 0.9628666666666666
# Cost after 2480 iterations: 0.0229165879416867
# Accuraxy after 2480 iterations: 0.9619166666666666
# Cost after 2490 iterations: 0.025050446188011527
# Accuraxy after 2490 iterations: 0.9571666666666667
# Cost after 2500 iterations: 0.2650772401544354
# Accuraxy after 2500 iterations: 0.36845
# Cost after 2510 iterations: 0.1327936572955666
# Accuraxy after 2510 iterations: 0.7066666666666667
# Cost after 2520 iterations: 0.08482935825711563
# Accuraxy after 2520 iterations: 0.8327166666666667
# Cost after 2530 iterations: 0.07286970633211823
# Accuraxy after 2530 iterations: 0.8610666666666666
# Cost after 2540 iterations: 0.07978579285668501
# Accuraxy after 2540 iterations: 0.8506
# Cost after 2550 iterations: 0.06204816070860248
# Accuraxy after 2550 iterations: 0.8855166666666666
# Cost after 2560 iterations: 0.06950868028845561
# Accuraxy after 2560 iterations: 0.8746833333333334
# Cost after 2570 iterations: 0.055373130274522286
# Accuraxy after 2570 iterations: 0.8991166666666667
# Cost after 2580 iterations: 0.05539431631316985
# Accuraxy after 2580 iterations: 0.8993166666666667
# Cost after 2590 iterations: 0.06403437030147871
# Accuraxy after 2590 iterations: 0.8810833333333333
# Cost after 2600 iterations: 0.04998114272424332
# Accuraxy after 2600 iterations: 0.9117166666666666
# Cost after 2610 iterations: 0.04997014585710964
# Accuraxy after 2610 iterations: 0.9123166666666667
# Cost after 2620 iterations: 0.05651550711032105
# Accuraxy after 2620 iterations: 0.9005
# Cost after 2630 iterations: 0.04796890645778261
# Accuraxy after 2630 iterations: 0.9143666666666667
# Cost after 2640 iterations: 0.04732848376243546
# Accuraxy after 2640 iterations: 0.9157333333333333
# Cost after 2650 iterations: 0.047754151769724286
# Accuraxy after 2650 iterations: 0.915
# Cost after 2660 iterations: 0.04679659911947513
# Accuraxy after 2660 iterations: 0.91775
# Cost after 2670 iterations: 0.04803794451518148
# Accuraxy after 2670 iterations: 0.9167833333333333
# Cost after 2680 iterations: 0.04521240045952515
# Accuraxy after 2680 iterations: 0.9224333333333333
# Cost after 2690 iterations: 0.04201165876027132
# Accuraxy after 2690 iterations: 0.9277
# Cost after 2700 iterations: 0.041582002315546235
# Accuraxy after 2700 iterations: 0.9281666666666667
# Cost after 2710 iterations: 0.04702642249920686
# Accuraxy after 2710 iterations: 0.91665
# Cost after 2720 iterations: 0.04948431566334456
# Accuraxy after 2720 iterations: 0.9158833333333334
# Cost after 2730 iterations: 0.0421213509318703
# Accuraxy after 2730 iterations: 0.9267166666666666
# Cost after 2740 iterations: 0.04091135435194595
# Accuraxy after 2740 iterations: 0.92855
# Cost after 2750 iterations: 0.040205341315422485
# Accuraxy after 2750 iterations: 0.9299
# Cost after 2760 iterations: 0.039689730363162756
# Accuraxy after 2760 iterations: 0.931
# Cost after 2770 iterations: 0.039433699160425134
# Accuraxy after 2770 iterations: 0.9321833333333334
# Cost after 2780 iterations: 0.04309336042484704
# Accuraxy after 2780 iterations: 0.92645
# Cost after 2790 iterations: 0.04192389480905297
# Accuraxy after 2790 iterations: 0.9272833333333333
# Cost after 2800 iterations: 0.039218741951322064
# Accuraxy after 2800 iterations: 0.9323333333333333
# Cost after 2810 iterations: 0.03856580303879818
# Accuraxy after 2810 iterations: 0.9334333333333333
# Cost after 2820 iterations: 0.038121033985171526
# Accuraxy after 2820 iterations: 0.9343166666666667
# Cost after 2830 iterations: 0.037754448419885636
# Accuraxy after 2830 iterations: 0.9347833333333333
# Cost after 2840 iterations: 0.03742899079011301
# Accuraxy after 2840 iterations: 0.9355833333333333
# Cost after 2850 iterations: 0.03713335782912022
# Accuraxy after 2850 iterations: 0.9363333333333334
# Cost after 2860 iterations: 0.03686652336583125
# Accuraxy after 2860 iterations: 0.9366833333333333
# Cost after 2870 iterations: 0.036623642166264625
# Accuraxy after 2870 iterations: 0.9370833333333334
# Cost after 2880 iterations: 0.0363999824259437
# Accuraxy after 2880 iterations: 0.93745
# Cost after 2890 iterations: 0.03627699326942733
# Accuraxy after 2890 iterations: 0.9375166666666667
# Cost after 2900 iterations: 0.03682019588430158
# Accuraxy after 2900 iterations: 0.936
# Cost after 2910 iterations: 0.0440028384005638
# Accuraxy after 2910 iterations: 0.9207
# Cost after 2920 iterations: 0.037731561893570804
# Accuraxy after 2920 iterations: 0.9329666666666667
# Cost after 2930 iterations: 0.03567005880335602
# Accuraxy after 2930 iterations: 0.9389
# Cost after 2940 iterations: 0.03570026225546962
# Accuraxy after 2940 iterations: 0.9385
# Cost after 2950 iterations: 0.04181779132598667
# Accuraxy after 2950 iterations: 0.9271
# Cost after 2960 iterations: 0.048600454279931836
# Accuraxy after 2960 iterations: 0.91835
# Cost after 2970 iterations: 0.038775883416900754
# Accuraxy after 2970 iterations: 0.9336333333333333
# Cost after 2980 iterations: 0.037109480543945875
# Accuraxy after 2980 iterations: 0.93635
# Cost after 2990 iterations: 0.03630074631028714
# Accuraxy after 2990 iterations: 0.9379333333333333

# %%
def predict(X, params, layer_dims=layer_dims):
    preds, _= forward_prop(X, params, layer_dims)
    labels = np.argmax(preds,0)

    return labels

# %%
y_pred = predict(x_test, params)

# %%
get_accuracy(y_pred, y_test)
# Out:
# 0.9331
